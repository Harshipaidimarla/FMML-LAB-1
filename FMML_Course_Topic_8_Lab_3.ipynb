# %% [markdown]
# <a href="https://colab.research.google.com/github/Harshipaidimarla/FMML-LAB-1/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-05-20 14:35:37--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.110.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   267MB/s    in 0.3s
#
# 2024-05-20 14:35:38 (267 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 9545   1705.08844v1  The knowledge representation community has bui...    cs
# 25545  1510.00477v1  What makes an image appear realistic? In this ...    cs
# 10256   1002.4658v2  We consider the dimensionality-reduction probl...  stat
# 4957   1705.08500v2  Selective classification techniques (also know...    cs
# 31897   1203.0298v2  In this paper, we study the application of GIS...    cs
# ...             ...                                                ...   ...
# 7731   1803.00212v1  Phase retrieval (PR) algorithms have become an...  stat
# 29982  1711.03874v1  We question the dominant role of real-world tr...    cs
# 12250  1710.10733v2  The Madry Lab recently hosted a competition de...  stat
# 22465  1608.03817v3  Factorial Hidden Markov Models (FHMMs) are pow...  stat
# 7314   1711.09163v1  The problem of feature disentanglement has bee...    cs
#
#                                                    title  year  \
# 9545   How a General-Purpose Commonsense Ontology can...  2017
# 25545  Learning a Discriminative Model for the Percep...  2015
# 10256  Principal Component Analysis with Contaminated...  2010
# 4957   Selective Classification for Deep Neural Networks  2017
# 31897        Application of Gist SVM in Cancer Detection  2012
# ...                                                  ...   ...
# 7731   prDeep: Robust Phase Retrieval with Flexible D...  2018
# 29982  Material Classification in the Wild: Do Synthe...  2017
# 12250  Attacking the Madry Defense Model with $L_1$-b...  2017
# 22465  Scaling Factorial Hidden Markov Models: Stocha...  2016
# 7314       JADE: Joint Autoencoders for Dis-Entanglement  2017
#
#                                                 keywords
# 9545   [knowledge, representation, community, ontolog...
# 25545  [realistic, answering, perspective, perception...
# 10256  [dimensionality, reduction, approximation, con...
# 4957   [selective, classification, techniques, consid...
# 31897  [application, prediction, classification, effe...
# ...                                                  ...
# 7731   [retrieval, algorithms, important, component, ...
# 29982  [classification, investigating, synthesized, g...
# 12250  [competition, robustness, adversarially, const...
# 22465  [factorial, sequential, sequences, inference, ...
# 7314   [disentanglement, literature, processing, dise...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 9545     [knowledge, representation, community, ontolog...
# 25545    [realistic, answering, perspective, perception...
# 10256    [dimensionality, reduction, approximation, con...
# 4957     [selective, classification, techniques, consid...
# 31897    [application, prediction, classification, effe...
#                                ...
# 36664    [reference, development, chatterbots, implemen...
# 2771     [reinforcement, challenge, objective, physiolo...
# 40995    [complexity, approximation, functions, distrib...
# 19057    [distributed, knowledge, applications, informa...
# 11616    [interesting, concentrate, dimensional, manifo...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8800 words.
# Out of those 4636 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="76f6b3c5-2a05-457d-98e9-dbf20b2c3c67" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("76f6b3c5-2a05-457d-98e9-dbf20b2c3c67")) {                    Plotly.newPlot(                        "76f6b3c5-2a05-457d-98e9-dbf20b2c3c67",                        [{"x":["experiments","recognition","specifically","knowledge","approaches","performance","detectors","conclusion","consequently","relations","including","representation","technique","community","retrieval","conceptnet","benchmark","information","reasoning","commonsense","meaningful","ontologies","incorporates","outperforms","distinguishes","perspective","predicted","convolutional","heuristics","compatibility","answering","photographs","annotations","automatically","advantage","perception","unrealistic","demonstrate","classifying","composite","realistic","parameters","particular","discriminative","generated","pertaining","furthermore","variables","algorithms","deviation","principal","dimensionality","contaminated","proportion","resulting","reduction","dimensional","observation","robustness","approximation","magnitude","optimality","component","algorithm","corrupted","observations","breakdown","tractable","construct","selective","classification","guaranteed","potentially","empirical","unprecedented","applications","possibilities","significantly","convincingly","techniques","classifier","viability","considered","prediction","probability","instances","effectively","malignant","selection","experimented","different","application","determine","differentiate","detection","explanatory","situation","reproducing","functional","covariate","methodology","estimating","extending","regression","borrowing","covariates","nonparametric","continuous","efficient","computational","motivates","realworld","inference","resources","preserving","intrinsically","deployment","appealing","extensive","alternating","optimization","connection","independence","regularized","characterize","correctly","parametric","introduced","sufficiently","numerical","conditional","stationary","direction","originally","estimates","generalization","processes","multipliers","likelihood","theoretically","graphical","independently","increasing","similarities","architecture","collected","normalized","statistical","operations","developed","combination","forecasting","irradiance","penetration","laboratory","similarity","distinctions","performed","validated","respectively","renewable","horizontal","framework","approximate","introduce","intelligence","accurately","effective","challenges","accumulated","simulator","represented","artificial","accumulates","architectures","conventional","predictions","designing","attributes","representations","attribute","precisely","adjacency","structures","structured","characterized","molecules","attention","relationships","arbitrarily","interests","correspondence","relational","aggregation","aggregated","compounds","neighborhood","independent","resultant","dictionary"],"y":[563,360,171,341,443,890,35,13,39,89,233,359,243,66,106,6,216,691,148,5,48,32,39,260,3,78,41,390,48,7,49,10,68,179,102,29,6,552,38,11,67,238,293,89,176,10,157,148,621,10,33,60,6,12,134,109,203,62,94,148,59,18,102,832,21,89,3,34,74,16,465,29,44,150,12,426,15,245,1,393,156,8,148,234,190,106,125,2,159,7,740,261,82,8,334,1,24,7,47,2,77,68,24,120,4,3,15,113,422,307,10,4,232,57,58,8,16,18,162,32,322,45,40,35,51,24,43,124,22,83,105,28,71,18,70,111,115,9,69,38,61,33,98,36,248,56,29,174,67,217,134,24,1,3,11,159,6,118,26,86,0,6,575,113,318,88,58,250,132,7,10,80,145,2,111,102,78,44,70,254,44,34,6,151,98,25,2,169,63,16,16,25,36,25,17,0,27,130,11,47],"type":"bar"},{"x":["experiments","recognition","specifically","knowledge","approaches","perfo ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4636,), (4636, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.81

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>A</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Probabilistic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Framework</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333326);'>Representing</span> <span style=''>Dialog</span> <span style=''>Systems</span> <span style=''>and</span> <span style=''>Entropy</span> <span style=''>Based</span> <span style=''>Dialog</span> <span style='background-color:rgba(0, 255, 0, 0.7391304347826086);'>Management</span> <span style=''>through</span> <span style=''>Dynamic</span> <span style='background-color:rgba(255, 0, 0, 0.39641943734015345);'>Stochastic</span> <span style=''>State</span> <span style='background-color:rgba(0, 255, 0, 0.5483870967741935);'>Evolution</span> <br/><br/><span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>present</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probabilistic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>framework</span> <span style=''>for</span> <span style=''>goal</span> <span style=''>driven</span> <span style=''>spoken</span> <span style=''>dialog</span> <span style=''>systems</span> <span style=''>A</span> <span style=''>new</span> <span style=''>dynamic</span> <span style='background-color:rgba(255, 0, 0, 0.39641943734015345);'>stochastic</span> <span style=''>state</span> <span style=''>(DS</span> <span style=''>state)</span> <span style=''>is</span> <span style=''>then</span> <span style=''>defined</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>characterize</span> <span style=''>the</span> <span style=''>goal</span> <span style=''>set</span> <span style=''>of</span> <span style=''>a</span> <span style=''>dialog</span> <span style=''>state</span> <span style=''>at</span> <span style='background-color:rgba(0, 255, 0, 0.3155555555555556);'>different</span> <span style=''>stages</span> <span style=''>of</span> <span style=''>the</span> <span style=''>dialog</span> <span style=''>process</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Furthermore</span> <span style=''>an</span> <span style=''>entropy</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>minimization</span> <span style=''>dialog</span> <span style=''>management(EMDM)</span> <span style=''>strategy</span> <span style=''>is</span> <span style=''>also</span> <span style=''>proposed</span> <span style=''>to</span> <span style=''>combine</span> <span style=''>with</span> <span style=''>the</span> <span style=''>DS</span> <span style=''>states</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.45762711864406774);'>facilitate</span> <span style=''>a</span> <span style=''>robust</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficient</span> <span style=''>solution</span> <span style=''>in</span> <span style=''>reaching</span> <span style=''>a</span> <span style=''>users</span> <span style=''>goals</span> <span style=''>A</span> <span style=''>Song</span> <span style=''>On</span> <span style=''>Demand</span> <span style=''>task</span> <span style=''>with</span> <span style=''>a</span> <span style=''>total</span> <span style=''>of</span> <span style=''>38117</span> <span style=''>songs</span> <span style=''>and</span> <span style=''>12</span> <span style='background-color:rgba(0, 255, 0, 0.4141414141414141);'>attributes</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>corresponding</span> <span style=''>to</span> <span style=''>each</span> <span style=''>song</span> <span style=''>is</span> <span style=''>used</span> <span style=''>to</span> <span style=''>test</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style=''>of</span> <span style=''>the</span> <span style=''>proposed</span> <span style='' ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Graph</span> <span style=''>Valued</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Regression</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.3);'>Undirected</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>graphical</span> <span style=''>models</span> <span style=''>encode</span> <span style=''>in</span> <span style=''>a</span> <span style=''>graph</span> <span style=''>G</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dependency</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structure</span> <span style=''>of</span> <span style=''>a</span> <span style=''>random</span> <span style=''>vector</span> <span style=''>Y</span> <span style=''>In</span> <span style=''>many</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>applications</span> <span style=''>it</span> <span style=''>is</span> <span style=''>of</span> <span style=''>interest</span> <span style=''>to</span> <span style=''>model</span> <span style=''>Y</span> <span style=''>given</span> <span style=''>another</span> <span style=''>random</span> <span style=''>vector</span> <span style=''>X</span> <span style=''>as</span> <span style=''>input</span> <span style=''>We</span> <span style=''>refer</span> <span style=''>to</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimating</span> <span style=''>the</span> <span style=''>graph</span> <span style=''>G(x)</span> <span style=''>of</span> <span style=''>Y</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conditioned</span> <span style=''>on</span> <span style=''>Xx</span> <span style=''>as</span> <span style=''>graph</span> <span style=''>valued</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regression</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>semiparametric</span> <span style=''>method</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimating</span> <span style=''>G(x)</span> <span style=''>that</span> <span style=''>builds</span> <span style=''>a</span> <span style=''>tree</span> <span style=''>on</span> <span style=''>the</span> <span style=''>X</span> <span style=''>space</span> <span style=''>just</span> <span style=''>as</span> <span style=''>in</span> <span style=''>CART</span> <span style=''>(classification</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regression</span> <span style=''>trees)</span> <span style=''>but</span> <span style=''>at</span> <span style=''>each</span> <span style=''>leaf</span> <span style=''>of</span> <span style=''>the</span> <span style=''>tree</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimates</span> <span style=''>a</span> <span style=''>graph</span> <span style=''>We</span> <span style=''>call</span> <span style=''>the</span> <span style=''>method</span> <span style=''>Graph</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimized</span> <span style=''>CART</span> <span style=''>or</span> <span style=''>Go</span> <span style=''>CART</span> <span style=''>We</span> <span style=''>study</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>theoretical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>properties</span> <span style=''>of</span> <span style=''>Go</span> <span style=''>CART</span> <span style=''>using</span> <span style=''>dyadic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>partitioning</span> <span style=''>trees</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>establishing</span> <span style=''>oracle</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inequalities</span> <span style=''>on ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Conditional</span> <span style=''>Sparse</span> <span style=''>Coding</span> <span style=''>and</span> <span style=''>Grouped</span> <span style='background-color:rgba(255, 0, 0, 0.6909090909090909);'>Multivariate</span> <span style='background-color:rgba(255, 0, 0, 0.5180722891566265);'>Regression</span> <br/><br/><span style=''>We</span> <span style=''>study</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.6909090909090909);'>multivariate</span> <span style='background-color:rgba(255, 0, 0, 0.5180722891566265);'>regression</span> <span style=''>where</span> <span style=''>the</span> <span style=''>data</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>naturally</span> <span style=''>grouped</span> <span style=''>and</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.5180722891566265);'>regression</span> <span style=''>matrix</span> <span style=''>is</span> <span style=''>to</span> <span style=''>be</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>estimated</span> <span style=''>for</span> <span style=''>each</span> <span style=''>group</span> <span style=''>We</span> <span style=''>propose</span> <span style=''>an</span> <span style=''>approach</span> <span style=''>in</span> <span style=''>which</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dictionary</span> <span style=''>of</span> <span style=''>low</span> <span style=''>rank</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>parameter</span> <span style=''>matrices</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>estimated</span> <span style=''>across</span> <span style=''>groups</span> <span style=''>and</span> <span style=''>a</span> <span style=''>sparse</span> <span style=''>linear</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>combination</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dictionary</span> <span style=''>elements</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>estimated</span> <span style=''>to</span> <span style=''>form</span> <span style=''>a</span> <span style=''>model</span> <span style=''>within</span> <span style=''>each</span> <span style=''>group</span> <span style=''>We</span> <span style=''>refer</span> <span style=''>to</span> <span style=''>the</span> <span style=''>method</span> <span style=''>as</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conditional</span> <span style=''>sparse</span> <span style=''>coding</span> <span style=''>since</span> <span style=''>it</span> <span style=''>is</span> <span style=''>a</span> <span style=''>coding</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>procedure</span> <span style=''>for</span> <span style=''>the</span> <span style=''>response</span> <span style=''>vectors</span> <span style=''>Y</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>conditioned</span> <span style=''>on</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.75);'>covariate</span> <span style=''>vectors</span> <span style=''>X</span> <span style=''>This</span> <span style=''>approach</span> <span style=''>captures</span> <span style=''>the</span> <span style=''>shared</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>information</span> <span style=''>across</span> <span style=''>the</span> <span style=''>groups</span> <span style=''>while</span> <span style=''>adapting</span> <span style=''>to</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structure</span> <span style=''>within</span> <span style=''>each</span> <span style=''>group</span> <span style=''>It</span> <span style=''>exploits</span> <span style=''>the</spa ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Dependence</span> <span style=''>of</span> <span style=''>Machine</span> <span style=''>Learning</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Electronic</span> <span style=''>Medical</span> <span style=''>Record</span> <span style=''>Quality</span> <br/><br/><span style=''>There</span> <span style=''>is</span> <span style=''>growing</span> <span style=''>interest</span> <span style=''>in</span> <span style=''>applying</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>methods</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Electronic</span> <span style=''>Medical</span> <span style=''>Records</span> <span style=''>(EMR)</span> <span style=''>Across</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>different</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>institutions</span> <span style=''>however</span> <span style=''>EMR</span> <span style=''>quality</span> <span style=''>can</span> <span style=''>vary</span> <span style=''>widely</span> <span style=''>This</span> <span style=''>work</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>investigated</span> <span style=''>the</span> <span style=''>impact</span> <span style=''>of</span> <span style=''>this</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>disparity</span> <span style=''>on</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performance</span> <span style=''>of</span> <span style=''>three</span> <span style=''>advanced</span> <span style=''>machine</span> <span style=''>learning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style=''>logistic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regression</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>multilayer</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>perceptron</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>recurrent</span> <span style=''>neural</span> <span style=''>network</span> <span style=''>The</span> <span style=''>EMR</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>disparity</span> <span style=''>was</span> <span style=''>emulated</span> <span style=''>using</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>different</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>permutations</span> <span style=''>of</span> <span style=''>the</span> <span style=''>EMR</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>collected</span> <span style=''>at</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Childrens</span> <span style=''>Hospital</span> <span style=''>Los</span> <span style=''>Angeles</span> <span style=''>(CHLA)</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Pediatric</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Intensive</span> <span style=''>Care</span> <span style=''>Unit</span> <span style=''>(PICU)</span> <span style=''>and</span> <span style=''>Cardiothoracic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Intensive</span> <span style=''>Care</span> <span style=''>Unit</span> <span style=''>(CTICU)</span> <span style=''>The</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style=''>were</span> <span style=''>trained</span> <span style=''>using</span> <span style=''>patients</span> <span style=''>from</span> <span style=''>the</span> <span style=''>PICU</span> <span style=''>to</span> <span style=''>predict</span> <span style=''>in</span> <span style=''>ICU</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>mortality</span> <span style=''>for</span> <span style=''>patients</span> <span style=''>in</span> <span style=''>a</span> <span style=''>held</span> <span style=''>out</span> <span style=''>set< ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	representation (0.12881234302116973)
# 	architecture (0.08898457122353785)
# 	segmentation (0.06925008970218874)
# 	processing (0.11445999282382491)
# 	experimental (0.1359885181198421)
# 	information (0.24793684965913168)
# 	detection (0.1198421241478292)
# 	different (0.2655184786508791)
# 	recognition (0.12917115177610333)
# 	convolutional (0.13993541442411195)
#
# Some Statistics words are:
# 	variables (0.14008941877794337)
# 	statistical (0.15002483854942872)
# 	algorithm (0.3869846000993542)
# 	stochastic (0.13561847988077497)
# 	distribution (0.17536015896671633)
# 	estimation (0.17337307501241928)
# 	theoretical (0.15250869349230006)
# 	inference (0.18976651763537009)
# 	dimensional (0.18132141082960754)
# 	regression (0.18777943368107303)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="5cc624fd-0b74-4abf-9b29-0126a3e8a24b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5cc624fd-0b74-4abf-9b29-0126a3e8a24b")) {                    Plotly.newPlot(                        "5cc624fd-0b74-4abf-9b29-0126a3e8a24b",                        [{"x":["experiments","recognition","specifically","knowledge","approaches","performance","detectors","conclusion","consequently","relations","including","representation","technique","community","retrieval","conceptnet","benchmark","information","reasoning","commonsense","meaningful","ontologies","incorporates","outperforms","distinguishes","perspective","predicted","convolutional","heuristics","compatibility","answering","photographs","annotations","automatically","advantage","perception","unrealistic","demonstrate","classifying","composite","realistic","parameters","particular","discriminative","generated","pertaining","furthermore","variables","algorithms","deviation","principal","dimensionality","contaminated","proportion","resulting","reduction","dimensional","observation","robustness","approximation","magnitude","optimality","component","algorithm","corrupted","observations","breakdown","tractable","construct","selective","classification","guaranteed","potentially","empirical","unprecedented","applications","possibilities","significantly","convincingly","techniques","classifier","viability","considered","prediction","probability","instances","effectively","malignant","selection","experimented","different","application","determine","differentiate","detection","explanatory","situation","reproducing","functional","covariate","methodology","estimating","extending","regression","borrowing","covariates","nonparametric","continuous","efficient","computational","motivates","realworld","inference","resources","preserving","intrinsically","deployment","appealing","extensive","alternating","optimization","connection","independence","regularized","characterize","correctly","parametric","introduced","sufficiently","numerical","conditional","stationary","direction","originally","estimates","generalization","processes","multipliers","likelihood","theoretically","graphical","independently","increasing","similarities","architecture","collected","normalized","statistical","operations","developed","combination","forecasting","irradiance","penetration","laboratory","similarity","distinctions","performed","validated","respectively","renewable","horizontal","framework","approximate","introduce","intelligence","accurately","effective","challenges","accumulated","simulator","represented","artificial","accumulates","architectures","conventional","predictions","designing","attributes","representations","attribute","precisely","adjacency","structures","structured","characterized","molecules","attention","relationships","arbitrarily","interests","correspondence","relational","aggregation","aggregated","compounds","neighborhood","independent","resultant","dictionary","interpret","chemistry","correspond","molecular","fingerprints","important","properties","predefined","mechanism","convolution","transformation","generates","approximated","illustrate","implemented","existence","semantics","specification","integration","corresponding","individual","contextual","experimental","distribution","specially","regularization","generative","distributions","consideration","conditioned","attracted","verification","transition","comparing","adversarial","procedure","multimedia","synthesized","distinguish","describes","quadratic","evaluated","locations","interpretation","measurements","represents","proportional","covariance","associated","estimation","reconstruction","formulated","posterior","estimator","awareness", ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	renewable
# 	compounds
# 	eigendecomposition
# 	blockmodel
# 	conjugacy
# 	penalization
# 	preconditioning
# 	couplings
# 	equitability
# 	anchoring
# 	hoeffding
# 	irregularly
# 	unsatisfying
# 	terminate
# 	nonstandard
# 	heckerman
# 	archetypal
# 	similitude
# 	factorize
# 	tsybakovs
# Some words which never appear in Statistics papers:
# 	conceptnet
# 	commonsense
# 	photographs
# 	experimented
# 	differentiate
# 	realworld
# 	accomplishing
# 	synchronized
# 	automaton
# 	defending
# 	inversely
# 	articulated
# 	deformation
# 	integrity
# 	electroencephalogram
# 	satisfiable
# 	equipping
# 	offspring
# 	pseudoinverse
# 	pronunciation

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.07635513443672e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7625
